# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelAngel-ht/Image_Processing_/blob/main/TAREA_3_OPEN_BYTES_MATRIX_CUT_SAVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image      
import matplotlib.pyplot as plt
import numpy as np

# %%
files = ['C1','C2','C3','C4']
images = []; img_arr = []

# READ AND SAVE ALL IN A LIST

for i in files:
  images.append(Image.open(i+'.jpg'))
  img_arr.append(np.array(Image.open(i+'.jpg')))

# %%
byts = []
for i,j in enumerate(images):
  byts.append(len(j.fp.read()))
  print('El archivo ' + files[i]+'.jpg pesa ',byts[i],' bytes')
# Out:
# El archivo C1.jpg pesa  1032436  bytes
# El archivo C2.jpg pesa  119481  bytes
# El archivo C3.jpg pesa  640076  bytes
# El archivo C4.jpg pesa  131135  bytes

# %%
for i,j in enumerate(img_arr):
  print('El archivo ' + files[i]+'.jpg pesa ',j.nbytes,' bytes')
# Out:
# El archivo C1.jpg pesa  12288000  bytes
# El archivo C2.jpg pesa  2359296  bytes
# El archivo C3.jpg pesa  6912000  bytes
# El archivo C4.jpg pesa  3264000  bytes

# %%
for i,j in enumerate(files):
  print(j+" matriz / "+j+".jpg  = ",img_arr[i].nbytes / byts[i] )
# Out:
# C1 matriz / C1.jpg  =  11.901948401644267
# C2 matriz / C2.jpg  =  19.746202325055865
# C3 matriz / C3.jpg  =  10.798717652278793
# C4 matriz / C4.jpg  =  24.890380142601135

# %%
centers = []
for i in img_arr:
  y = int(np.shape(i)[0]/2) - 256
  x = int(np.shape(i)[1]/2) - 256
  centers.append(i[y:y+512,x:x+512])

# %%
h0 = np.append(centers[0],centers[1],axis=1)
h1 = np.append(centers[2],centers[3],axis=1)
Im5 = np.append(h0,h1,axis=0)

# %%
plt.imshow(Im5)
plt.show()

# %%
plt.plot(Im5[256,:,0],c='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(Im5[256,:,2])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Im5 = Image.fromarray(Im5)   # CONVERTION TO IMAGE OBJECT
Im5.save('Im5.png')
Im5.save('Im5.bmp')
Im5.save('Im5.jpg')

# %%
for i in ['Im5.png','Im5.bmp','Im5.jpg']:
  images.append(Image.open(i))            # 4,5,6 index

# %%
for i,j in enumerate(['Im5.png','Im5.bmp','Im5.jpg']):
  print('Archivo '+j+' pesa ',len(images[i+4].fp.read()),' bytes')
# Out:
# Archivo Im5.png pesa  1351582  bytes
# Archivo Im5.bmp pesa  3145728  bytes
# Archivo Im5.jpg pesa  135227  bytes

# %%
# MATRIX WHITE

# a = np.full((1024,1024,3), 255) 
# Im5 = Image.fromarray(a.astype(np.uint8), 'RGB')

# %%
# im = Image.fromarray(a)  # ARRAY TO IMAGE
